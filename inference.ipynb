# %%
import inference
import model

ckpt_path = "./lightning_logs/version_142/checkpoints/epoch=39-step=2320.ckpt"
unet = model.UNet(
        loss_fn="dice",
        contract_method="mp",
        expand_method="tr"
    )

inference.plot_inference(ckpt_path, unet)
# Out:
# torch.Size([1, 128, 128])
